# %% [markdown]
#     Facilidad
#
#     Disminución de la cantidad de código
#
#     Super versátil
#
#     Gran comunidad y librerías para abstraer complejidad y hacer el desarrollo más rápido

# %% [markdown]
# Instalación de python

# %%
## Creación de un ambiente virtual y activación

# En Linux/MacOS

python -m venv venv

source venv/bin/activate

# Lo anterior dentro de la carpeta del proyecto que va a requerir las dependencias específicas que no queremos instalar globalmente.
