# %% [markdown]
# Recordar que las listas en python son los array
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Los Sets son listas/arrays cuyos elementos no pueden ser ordenados, son inmutables y no admiten valores duplicados
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Valor lógico simple
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
