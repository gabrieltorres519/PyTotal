# %% [markdown]
# # Naming

# %% [markdown]
# Regla 1: Legible
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Regla 2: Unidad
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Regla 3: Hispanismos
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Regla 4: Números
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Regla 5: Signos
#
#
# [No debe contener ninguno de los siguientes símbolos]
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Rela 6: Palabras clave
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
